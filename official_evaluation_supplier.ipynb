# %%
import sys
import os
from selenium import webdriver
import path
import time
import re
from bs4 import BeautifulSoup as bs
from bs4 import BeautifulSoup
import pathlib
import joblib
import numpy as np
import json
import gzip
from selenium import webdriver
import path
import requests
import urllib, json
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegression
import joblib
import datetime

from sklearn.datasets import load_breast_cancer
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


driver = webdriver.Chrome(executable_path="C:\chromedriver_win32\chromedriver.exe")

# %%
# contents = ['sản phẩm tệ', 'sản phẩm tồi', 'sản phẩm tốt']
# stars = [3,3,4]
# vectorizer = CountVectorizer()
# vectorizer.fit(contents)
# X_train = vectorizer.transform(contents)

# y_train=[]

# numNega=0
# numPosi=0
# for i in stars:
#     if i <= 3:
#         y_train.append(0)
#         numNega=numNega+1
#     else:
#         y_train.append(1)
#         numPosi=numPosi+1

# train_y = list(dict.fromkeys(y_train))

# classifier = LogisticRegression()
# classifier.fit(X_train, y_train)
# # tach ra 500 xau
# y_train=[]
# x_train=[]
# x_train_bad=[]
# x_train_good=[]

# total=0
# for i in range(0,len(stars)):
#     if(stars[i]<=3):
#         if(contents[i] not in x_train_bad):
#             y_train.append(0)
#             x_train_bad.append(contents[i])
#             x_train.append(contents[i])
#             total=total+1
#     if(total==500):
#         break

# total=0
# for i in range(0,len(stars)):
#     if(stars[i]>3):
#         if(contents[i] not in x_train_good):
#             y_train.append(1)
#             x_train_good.append(contents[i])
#             x_train.append(contents[i])
#             total=total+1
#     if(total==len(x_train_bad)):
#         break

# vectorizer = CountVectorizer()
# vectorizer.fit(x_train)
# X_train = vectorizer.transform(x_train)
# classifier = LogisticRegression()
# classifier.fit(X_train, y_train)
# count_negative = 0
# count_negative += classifier.predict(vectorizer.transform(['content']))
# count_positive = len(contents) - count_negative 

# count_negative = 0
# count_positive = 0
# for i in range(0,len(stars)):
#     if (stars[i] <= 3):
#         count_negative = count_negative + 1
#     else:
#         count_positive = count_positive + 1
# print (count_positive)
# print (count_negative)

# %%
def get_default(value ,value_null = None):
    if value.strip():
        return value
#     print("it's not an empty or blank string")
    else:
        return value_null
#     print("it's an empty or blank string")

# %%
def is_null_or_empty(string):
    if string.strip():
        return False
#     print("it's not an empty or blank string")
    else:
        return True
#     print("it's an empty or blank string")

# %%
#Lấy average của giá all products

#Lấy link từ danh mục
Link_Tiki = ['https://tiki.vn/binh-nuoc-binh-giu-nhiet-phu-kien/c6963?src=c.6963.hamburger_menu_fly_out_banner']

# %%
#chuỗi example: 'https://tiki.vn/binh-nuoc/c6963?src=c.6963.hamburger_menu_fly_out_banner'
# tìm ra vị trí của dấu / đầu tiên
result = Link_Tiki[0].find('/')
print(result)
#cắt chuỗi lấy tên danh mục
# cắt chuỗi từ https://tiki.vn/
split_name = [x[result+10:len(Link_Tiki[0])] for x in Link_Tiki]
print(split_name)
result = split_name[0].find('/')
print(result)
Name_Menu = [x[0:result] for x in split_name]
print(Name_Menu)

#chuỗi example: 'https://tiki.vn/binh-nuoc/c6963?src=c.6963.hamburger_menu_fly_out_banner'
# cắt chuỗi lấy id danh mục
# tìm ra vị trí của dấu / đầu tiên
result = Link_Tiki[0].find('/')
print(result)
# cắt chuỗi từ https://tiki.vn/
split_id = [x[result+10:len(Link_Tiki[0])] for x in Link_Tiki]
print(split_id)
#tìm ra chuỗi có dấu / chứa tên danh mục
result = split_id[0].find('/')
print(result)
#cắt chuỗi có chứa tên danh mục
split_id = [x[result+2:len(Link_Tiki[0])] for x in split_id]
print(split_id)
#lấy id của danh mục
result = split_id[0].find('?')
print(result)
Id_Link_Tiki = [x[0:result] for x in split_id]
print(Id_Link_Tiki)
# Out:
# 6
# ['binh-nuoc-binh-giu-nhiet-phu-kien/c6963?src=c.6963.hamburger_menu_fly_out_banner']
# 33
# ['binh-nuoc-binh-giu-nhiet-phu-kien']
# 6
# ['binh-nuoc-binh-giu-nhiet-phu-kien/c6963?src=c.6963.hamburger_menu_fly_out_banner']
# 33
# ['6963?src=c.6963.hamburger_menu_fly_out_banner']
# 4
# ['6963']

# %%
#in link json của link tiki
json_tiki ='https://tiki.vn/api/v2/products?limit=48&include=advertisement&aggregations=1&category=' + str(Id_Link_Tiki[0]) + '&page=1&src=c.' + str(Id_Link_Tiki[0]) + '.hamburger_menu_fly_out_banner&urlKey=' + str(Name_Menu[0])
#     print(https://tiki.vn/api/v2/products?limit=48&include=advertisement&aggregations=1&category=8214&page=1&src=c.8214.hamburger_menu_fly_out_banner&urlKey=phu-kien-dien-thoai-va-may-tinh-bang)
#lấy thông tin từ json_tiki trang chính
soup_tiki=""
driver.get(json_tiki)
page_source=(driver.page_source)
soup_tiki = bs(page_source,"lxml")
#     print(soup_tiki)
#lấy giá ở của sản phẩm
average_SP=[]

json_url = urllib.request.urlopen(json_tiki)
data = json.loads(json_url.read())
#Lấy ra các giá trị trong mục 'data'
content = data['data']

prices = []

for id in content:
    prices.append(id['price'])

#     print(prices)
# Tính average của giá thành các sản phẩm
average_price = round((sum(prices) / len(prices)), 2)
print(average_price)
# Out:
# 181987.4

# %%
#in link json của link tiki
json_tiki_1 ='https://tiki.vn/api/v2/products?limit=48&include=advertisement&aggregations=1&category=' + str(Id_Link_Tiki[0]) + '&page=1&src=c.' + str(Id_Link_Tiki[0]) + '.hamburger_menu_fly_out_banner&urlKey=' + str(Name_Menu[0])
json_tiki_2 ='https://tiki.vn/api/v2/products?limit=48&include=advertisement&aggregations=1&category=' + str(Id_Link_Tiki[0]) + '&page=2&src=c.' + str(Id_Link_Tiki[0]) + '.hamburger_menu_fly_out_banner&urlKey=' + str(Name_Menu[0])
# json_tiki_3 ='https://tiki.vn/api/v2/products?limit=48&include=advertisement&aggregations=1&category=' + str(Id_Link_Tiki[0]) + '&page=3&src=c.' + str(Id_Link_Tiki[0]) + '.hamburger_menu_fly_out_banner&urlKey=' + str(Name_Menu[0])
print(json_tiki_1)
print(json_tiki_2)
# print(json_tiki_3)
# Out:
# https://tiki.vn/api/v2/products?limit=48&include=advertisement&aggregations=1&category=6963&page=1&src=c.6963.hamburger_menu_fly_out_banner&urlKey=binh-nuoc-binh-giu-nhiet-phu-kien
# https://tiki.vn/api/v2/products?limit=48&include=advertisement&aggregations=1&category=6963&page=2&src=c.6963.hamburger_menu_fly_out_banner&urlKey=binh-nuoc-binh-giu-nhiet-phu-kien

# %%
#lấy thông tin từ json_tiki trang chính
# soup_tiki=""
# driver.get(json_tiki)
# page_source=(driver.page_source)
# soup_tiki = bs(page_source,"lxml")
# print(soup_tiki)

# %%
json_url = urllib.request.urlopen(json_tiki_1)
data = json.loads(json_url.read())
#Lấy ra các giá trị trong mục 'data'
content = data['data']

json_url = urllib.request.urlopen(json_tiki_2)
data = json.loads(json_url.read())
#Lấy ra các giá trị trong mục 'data'
content2 = data['data']

# json_url = urllib.request.urlopen(json_tiki_3)
# data = json.loads(json_url.read())
# #Lấy ra các giá trị trong mục 'data'
# content3 = data['data']

for item in content2:
    content.append(item)
# for item in content3:
#     content.append(item)

print(content)
# Out:
# [{'id': 83412126, 'sku': '3148826005430', 'name': 'Bình Giữ Nhiệt Lock&Lock Energetic One-Touch Tumbler LHC3249 - 550ML', 'url_key': 'binh-giu-nhiet-lock-lock-energetic-one-touch-tumbler-lhc3249-550ml-p83412126', 'url_path': 'binh-giu-nhiet-lock-lock-energetic-one-touch-tumbler-lhc3249-550ml-p83412126.html', 'type': 'configurable', 'brand_name': 'Lock&Lock', 'short_description': '\nBình Giữ Nhiệt Lock&amp;Lock Energetic One-Touch Tumbler LHC3249 - 550ML với thiết kế nắp mở một chạm dễ dàng: Đẩy sang trái để mở khóa đồng thời mở nắp.\nMiệng cốc rộng: Dễ dàng thêm đá viên và chùi...', 'price': 248000, 'list_price': 480000, 'badges': [{'code': 'tikinow', 'text': 'tikinow'}], 'badges_new': [{'placement': 'service', 'type': 'service_badge', 'code': 'tikinow', 'icon': 'https://salt.tikicdn.com/ts/upload/9f/32/dd/8a8d39d4453399569dfb3e80fe01de75.png', 'icon_width': 56, 'icon_height': 16, 'text': '', 'text_color': '#009900'}, {'placement': 'bottom', 'type': 'icon_badge', 'code': 'freeship_ti
# ...

# %%
# # Get id sản phẩm và link của các sản phẩm 
id_product = []
link_each_product = []
badges_primary = []
# chứa tiki now, Freeship, rẻ hơn hoàn tiền
badges_value = []
# chứa số lượng đã bán
quantity_sold = []
for item in content:
    id_product.append(item['id'])
    link_each_product.append('https://tiki.vn/' + str(item['url_path']))
    quantity_sell = item.get("quantity_sold", 0)
    if quantity_sell != 0:
        quantity_sold.append(quantity_sell['value'])
    else:
        quantity_sold.append(0)
print(id_product)
print('\n')
print(link_each_product)
# Out:
# [83412126, 111842814, 1726599, 11488920, 99868980, 99994000, 66621525, 73124602, 57763337, 55511631, 2153235, 73983551, 113617065, 1453915, 99621372, 19733027, 104270135, 1303927, 57046106, 61278429, 111843968, 74422509, 28324935, 42241386, 56880195, 16341786, 57045660, 19584471, 50324186, 8327610, 1575707, 8275143, 16690674, 20422266, 64988886, 75517779, 40938448, 28324641, 58852893, 5980477, 42270992, 21753141, 55424576, 107881796, 19273054, 423210, 1011168, 52151236, 75523543, 101302265, 604867, 700227, 1453913, 74238035, 25470491, 4581767, 36313228, 34139939, 8141095, 2562973, 67953082, 25800931, 57694353, 6278199, 74547434, 2297915, 36560504, 1726597, 4581755, 113445222, 39292323, 46248529, 71058774, 43330912, 50324146, 67416013, 101592040, 56375042, 22410333, 112243695, 52462193, 105717965, 1534875, 46104797, 712685, 72223014, 1726601, 109991914, 72013716, 107879022, 25305723, 49848183, 22099165, 10404390, 77662747, 2127575]
#
#
# ...

# %%
Link_Link = []
for item in id_product:
    id_link = link_each_product[id_product.index(item)]
    Link_Link.append(id_link)
print(Link_Link)
# Out:
# ['https://tiki.vn/binh-giu-nhiet-lock-lock-energetic-one-touch-tumbler-lhc3249-550ml-p83412126.html', 'https://tiki.vn/binh-dung-nuoc-3-5-lit-co-voi-sieu-tien-loi-p111842814.html', 'https://tiki.vn/binh-giu-nhiet-thep-khong-gi-vacuum-bottle-lock-lock-lhc6180fu-800ml-xanh-dam-p1726599.html', 'https://tiki.vn/binh-giu-nhiet-lock-lock-rigatumbler-897ml-p11488920.html', 'https://tiki.vn/binh-giu-nhiet-locknlock-bucket-tumbler-lhc4269-p99868980.html', 'https://tiki.vn/binh-giu-nhiet-co-ong-hut-lock-lock-bucket-tumbler-with-straw-lhc4268-p99994000.html', 'https://tiki.vn/binh-giu-nhiet-lock-lock-two-tone-clip-tumbler-lhc4151-540ml-p66621525.html', 'https://tiki.vn/binh-giu-nhiet-bang-thep-khong-gi-lock-lock-vacuum-bottle-lhc6180slv-800ml-p73124602.html', 'https://tiki.vn/binh-dung-nuoc-vo-lua-manh-an-toan-cao-cap-in-hinh-xuong-rong-totoro-giao-hang-theo-mau-ngau-nhien-p57763337.html', 'https://tiki.vn/chai-thuy-tinh-dung-nuoc-dung-tich-500ml-chiu-nhiet-tot-binh-thuy-tinh-kim-cuong-goc-canh
# ...

# %%
def writeToJson(ArrOutputData):
    y=json.dumps({"data":ArrOutputData},ensure_ascii=False).encode('utf8')
    a=json.loads(y)
    with open('tikijson.json', 'w',encoding='utf8') as f:
        json.dump(a, f,ensure_ascii=False)

# %%
# Danh sách stopword
stopword = set([':D','=>','❤❤','😆', '🥰','\n', '\n_' ,'a lô', 'a ha', 'ai', 'ai ai', 'ai nấy', 'ai đó', 'alô', 'amen', 'anh', 'anh ấy', 'ba', 'ba ba', 'ba bản', 'ba cùng', 'ba họ', 'ba ngày', 'ba ngôi', 'ba tăng', 'bao giờ', 'bao lâu', 'bao nhiêu', 'bao nả', 'bay biến', 'biết', 'biết bao', 'biết bao nhiêu', 'biết chắc', 'biết chừng nào', 'biết mình', 'biết mấy', 'biết thế', 'biết trước', 'biết việc', 'biết đâu', 'biết đâu chừng', 'biết đâu đấy', 'biết được', 'buổi', 'buổi làm', 'buổi mới', 'buổi ngày', 'buổi sớm', 'bà', 'bà ấy', 'bài', 'bài bác', 'bài bỏ', 'bài cái', 'bác', 'bán', 'bán cấp', 'bán dạ', 'bán thế', 'b
ằng', 'dù sao', 'dùng', 'dùng cho', 'dùng hết', 'dùng làm', 'dùng đến', 'dưới', 'dưới nước', 'dạ', 'dạ bán', 'dạ con', 'dạ dài', 'dạ dạ', 'dạ khách', 'dần dà', 'dần dần', 'dầu sao', 'dẫn', 'dẫu', 'dẫu mà', 'dẫu rằng', 'dẫu sao', 'dễ', 'dễ dùng', 'dễ gì', 'dễ khiến', 'dễ nghe', 'dễ ngươi', 'dễ như chơi', 'dễ sợ', 'dễ sử dụng', 'dễ thường', 'dễ thấy', 'dễ ăn', 'dễ đâu', 'dở chừng', 'dữ', 'dữ cách', 'em', 'em em', 'giá trị', 'giá trị thực tế', 'giảm', 'giảm chính', 'giảm thấp', 'giảm thế', 'giống', 'giống người', 'giống nhau', 'giống như', 'giờ', 'giờ lâu', 'giờ này', 'giờ đi', 'giờ đây', 'giờ đến', 'giữ', 'giữ lấy', 'giữ ý', 'giữa', 'giữa lúc', 'gây', 'gây cho', 'gây giống', 'gây ra', 'gây thêm', 'gì', 'gì gì', 'gì đó', 'gần', 'gần bên', 'gần hết', 'gần ngày', 'gần như', 'gần xa', 'gần đây', 'gần đến', 'gặp', 'gặp khó khăn', 'gặp phải', 'gồm', 'hay', 'hay biết', 'hay hay', 'hay không', 'hay là', 'hay làm', 'hay nhỉ', 'hay nói', 'hay sao', 'hay tin', 'hay đâu', 'hiểu', 'hiện nay', 'hiện tại', 'hoàn toàn', 'hoặc', 'hoặc là', 'hãy', 'hãy còn', 'hơn', 'hơn cả', 'hơn hết', 'hơn là', 'hơn nữa', 'hơn trước', 'hầu hết', 'hết', 'hết chuyện', 'hết cả', 'hết của', 'hết nói', 'hết ráo', 'hết rồi', 'hết ý', 'họ', 'họ gần', 'họ xa', 'hỏi', 'hỏi lại', 'hỏi xem', 'hỏi xin', 'hỗ trợ', 'khi', 'khi khác', 'khi không', 'khi nào', 'khi nên', 'khi trước', 'khiến', 'khoảng', 'khoảng cách', 'khoảng không', 'khá', 'khá tốt', 'khác', 'khác gì', 'khác khác', 'khác nhau', 'khác nào', 'khác thường', 'khác xa', 'khách', 'khó', 'khó biết', 'khó chơi', 'khó khăn', 'khó làm', 'khó mở', 'khó nghe', 'khó nghĩ', 'khó nói', 'khó thấy', 'khó tránh', 'không', 'không ai', 'không bao giờ', 'không bao lâu', 'không biết', 'không bán', 'không chỉ', 'không còn', 'không có', 'không có gì', 'không cùng', 'không cần', 'không cứ', 'không dùng', 'không gì', 'không hay', 'không khỏi', 'không kể', 'không ngoài', 'không nhận', 'không những', 'không phải', 'không phải không', 'không thể', 'không tính', 'không điều kiện', 'không được', 'không đầy', 'không để', 'khẳng định', 'khỏi', 'khỏi nói', 'kể', 'kể cả', 'kể như', 'kể tới', 'kể từ', 'liên quan', 'loại', 'loại từ', 'luôn', 'luôn cả', 'luôn luôn', 'luôn tay', 'là', 'là cùng', 'là là', 'là nhiều', 'là phải', 'là thế nào', 'là vì', 'là ít', 'làm', 'làm bằng', 'làm cho', 'làm dần dần', 'làm gì', 'làm lòng', 'làm lại', 'làm lấy', 'làm mất', 'làm ngay', 'làm như', 'làm nên', 'làm ra', 'làm riêng', 'làm sao', 'làm theo', 'làm thế nào', 'làm tin', 'làm tôi', 'làm tăng', 'làm tại', 'làm tắp lự', 'làm vì', 'làm đúng', 'làm được', 'lâu', 'lâu các', 'lâu lâu', 'lâu nay', 'lâu ngày', 'lên', 'lên cao', 'lên cơn', 'lên mạnh', 'lên ngôi', 'lên nước', 'lên số', 'lên xuống', 'lên đến', 'lòng', 'lòng không', 'lúc', 'lúc khác', 'lúc lâu', 'lúc nào', 'lúc này', 'lúc sáng', 'lúc trước', 'lúc đi', 'lúc đó', 'lúc đến', 'lúc ấy', 'lý do', 'lượng', 'lượng cả', 'lượng số', 'lượng từ', 'lại', 'lại bộ', 'lại cái', 'lại còn', 'lại giống', 'lại làm', 'lại người', 'lại nói', 'lại nữa', 'lại quả', 'lại thôi', 'lại ăn', 'lại đây', 'lấy', 'lấy có', 'lấy cả', 'lấy giống', 'lấy làm', 'lấy lý do', 'lấy lại', 'lấy ra', 'lấy ráo', 'lấy sau', 'lấy số', 'lấy thêm', 'lấy thế', 'lấy vào', 'lấy xuống', 'lấy được', 'lấy để', 'lần', 'lần khác', 'lần lần', 'lần nào', 'lần này', 'lần sang', 'lần sau', 'lần theo', 'lần trước', 'lần tìm', 'lớn', 'lớn lên', 'lớn nhỏ', 'lời', 'lời chú', 'lời nói', 'mang', 'mang lại', 'mang mang', 'mang nặng', 'mang về', 'muốn', 'mà', 'mà cả', 'mà không', 'mà lại', 'mà thôi', 'mà vẫn', 'mình', 'mạnh', 'mất', 'mất còn', 'mọi', 'mọi giờ', 'mọi khi', 'mọi lúc', 'mọi người', 'mọi nơi', 'mọi sự', 'mọi thứ', 'mọi việc', 'mối', 'mỗi', 'mỗi lúc', 'mỗi lần', 'mỗi một', 'mỗi ngày', 'mỗi người', 'một', 'một cách', 'một cơn', 'một khi', 'một lúc', 'một số', 'một vài', 'một ít', 'mới', 'mới hay', 'mới rồi', 'mới đây', 'mở', 'mở mang', 'mở nước', 'mở ra', 'mợ', 'mức', 'nay', 'ngay', 'ngay bây giờ', 'ngay cả', 'ngay khi', 'ngay khi đến', 'ngay lúc', 'ngay lúc này', 'ngay lập tức', 'ngay thật', 'ngay tức khắc', 'ngay tức thì', 'ngay từ', 'nghe', 'nghe chừng', 'nghe hiểu', 'nghe không', 'nghe lại', 'nghe nhìn', 'nghe như', 'nghe nói', 'nghe ra', 'nghe rõ', 'nghe thấy', 'nghe tin', 'nghe trực tiếp', 'nghe đâu', 'nghe đâu như', 'nghe được', 'nghen', 'nghiễm nhiên', 'nghĩ', 'nghĩ lại', 'nghĩ ra', 'nghĩ tới', 'nghĩ xa', 'nghĩ đến', 'nghỉm', 'ngoài', 'ngoài này', 'ngoài ra', 'ngoài xa', 'ngoải', 'nguồn', 'ngày', 'ngày càng', 'ngày cấp', 'ngày giờ', 'ngày ngày
ột', 'tuốt tuột', 'tuổi', 'tuổi cả', 'tuổi tôi', 'tà tà', 'tên', 'tên chính', 'tên cái', 'tên họ', 'tên tự', 'tênh', 'tênh tênh', 'tìm', 'tìm bạn', 'tìm cách', 'tìm hiểu', 'tìm ra', 'tìm việc', 'tình trạng', 'tính', 'tính cách', 'tính căn', 'tính người', 'tính phỏng', 'tính từ', 'tít mù', 'tò te', 'tôi', 'tôi con', 'tông tốc', 'tù tì', 'tăm tắp', 'tăng', 'tăng chúng', 'tăng cấp', 'tăng giảm', 'tăng thêm', 'tăng thế', 'tại', 'tại lòng', 'tại nơi', 'tại sao', 'tại tôi', 'tại vì', 'tại đâu', 'tại đây', 'tại đó', 'tạo', 'tạo cơ hội', 'tạo nên', 'tạo ra', 'tạo ý', 'tạo điều kiện', 'tấm', 'tấm bản', 'tấm các', 'tấn', 'tấn tới', 'tất cả', 'tất cả bao nhiêu', 'tất thảy', 'tất tần tật', 'tất tật', 'tập trung', 'tắp', 'tắp lự', 'tắp tắp', 'tọt', 'tỏ ra', 'tỏ vẻ', 'tốc tả', 'tối ư', 'tốt', 'tốt bạn', 'tốt bộ', 'tốt hơn', 'tốt mối', 'tốt ngày', 'tột', 'tột cùng', 'tớ', 'tới', 'tới gần', 'tới mức', 'tới nơi', 'tới thì', 'tức thì', 'tức tốc', 'từ', 'từ căn', 'từ giờ', 'từ khi', 'từ loại', 'từ nay', 'từ thế', 'từ tính', 'từ tại', 'từ từ', 'từ ái', 'từ điều', 'từ đó', 'từ ấy', 'từng', 'từng cái', 'từng giờ', 'từng nhà', 'từng phần', 'từng thời gian', 'từng đơn vị', 'từng ấy', 'tự', 'tự cao', 'tự khi', 'tự lượng', 'tự tính', 'tự tạo', 'tự vì', 'tự ý', 'tự ăn', 'tựu trung', 'veo', 'veo veo', 'việc', 'việc gì', 'vung thiên địa', 'vung tàn tán', 'vung tán tàn', 'và', 'vài', 'vài ba', 'vài người', 'vài nhà', 'vài nơi', 'vài tên', 'vài điều', 'vào', 'vào gặp', 'vào khoảng', 'vào lúc', 'vào vùng', 'vào đến', 'vâng', 'vâng chịu', 'vâng dạ', 'vâng vâng', 'vâng ý', 'vèo', 'vèo vèo', 'vì', 'vì chưng', 'vì rằng', 'vì sao', 'vì thế', 'vì vậy', 'ví bằng', 'ví dù', 'ví phỏng', 'ví thử', 'vô hình trung', 'vô kể', 'vô luận', 'vô vàn', 'vùng', 'vùng lên', 'vùng nước', 'văng tê', 'vượt', 'vượt khỏi', 'vượt quá', 'vạn nhất', 'vả chăng', 'vả lại', 'vấn đề', 'vấn đề quan trọng', 'vẫn', 'vẫn thế', 'vậy', 'vậy là', 'vậy mà', 'vậy nên', 'vậy ra', 'vậy thì', 'vậy ư', 'về', 'về không', 'về nước', 'về phần', 'về sau', 'về tay', 'vị trí', 'vị tất', 'vốn dĩ', 'với', 'với lại', 'với nhau', 'vở', 'vụt', 'vừa', 'vừa khi', 'vừa lúc', 'vừa mới', 'vừa qua', 'vừa rồi', 'vừa vừa', 'xa', 'xa cách', 'xa gần', 'xa nhà', 'xa tanh', 'xa tắp', 'xa xa', 'xa xả', 'xem', 'xem lại', 'xem ra', 'xem số', 'xin', 'xin gặp', 'xin vâng', 'xiết bao', 'xon xón', 'xoành xoạch', 'xoét', 'xoẳn', 'xoẹt', 'xuất hiện', 'xuất kì bất ý', 'xuất kỳ bất ý', 'xuể', 'xuống', 'xăm xúi', 'xăm xăm', 'xăm xắm', 'xảy ra', 'xềnh xệch', 'xệp', 'xử lý', 'yêu cầu', 'à', 'à này', 'à ơi', 'ào', 'ào vào', 'ào ào', 'á', 'á à', 'ái', 'ái chà', 'ái dà', 'áng', 'áng như', 'âu là', 'ít', 'ít biết', 'ít có', 'ít hơn', 'ít khi', 'ít lâu', 'ít nhiều', 'ít nhất', 'ít nữa', 'ít quá', 'ít ra', 'ít thôi', 'ít thấy', 'ô hay', 'ô hô', 'ô kê', 'ô kìa', 'ôi chao', 'ôi thôi', 'ông', 'ông nhỏ', 'ông tạo', 'ông từ', 'ông ấy', 'ông ổng', 'úi', 'úi chà', 'úi dào', 'ý', 'ý chừng', 'ý da', 'ý hoặc', 'ăn', 'ăn chung', 'ăn chắc', 'ăn chịu', 'ăn cuộc', 'ăn hết', 'ăn hỏi', 'ăn làm', 'ăn người', 'ăn ngồi', 'ăn quá', 'ăn riêng', 'ăn sáng', 'ăn tay', 'ăn trên', 'ăn về', 'đang', 'đang tay', 'đang thì', 'điều', 'điều gì', 'điều kiện', 'điểm', 'điểm chính', 'điểm gặp', 'điểm đầu tiên', 'đành đạch', 'đáng', 'đáng kể', 'đáng lí', 'đáng lý', 'đáng lẽ', 'đáng số', 'đánh giá', 'đánh đùng', 'đáo để', 'đâu', 'đâu có', 'đâu cũng', 'đâu như', 'đâu nào', 'đâu phải', 'đâu đâu', 'đâu đây', 'đâu đó', 'đây', 'đây này', 'đây rồi', 'đây đó', 'đã', 'đã hay', 'đã không', 'đã là', 'đã lâu', 'đã thế', 'đã vậy', 'đã đủ', 'đó', 'đó đây', 'đúng', 'đúng ngày', 'đúng ra', 'đúng tuổi', 'đúng với', 'đơn vị', 'đưa', 'đưa cho', 'đưa chuyện', 'đưa em', 'đưa ra', 'đưa tay', 'đưa tin', 'đưa tới', 'đưa vào', 'đưa về', 'đưa xuống', 'đưa đến', 'được', 'được cái', 'được lời', 'được nước', 'được tin', 'đại loại', 'đại nhân', 'đại phàm', 'đại để', 'đạt', 'đảm bảo', 'đầu tiên', 'đầy', 'đầy năm', 'đầy phè', 'đầy tuổi', 'đặc biệt', 'đặt', 'đặt làm', 'đặt mình', 'đặt mức', 'đặt ra', 'đặt trước', 'đặt để', 'đến', 'đến bao giờ', 'đến cùng', 'đến cùng cực', 'đến cả', 'đến giờ', 'đến gần', 'đến hay', 'đến khi', 'đến lúc', 'đến lời', 'đến nay', 'đến ngày', 'đến nơi', 'đến nỗi', 'đến thì', 'đến thế', 'đến tuổi', 'đến xem', 'đến điều', 'đến đâu', 'đều', 'đều bước', 'đều nhau', 'đều đều', 'để', 'để cho', 'để giống', 'để không', 'để lòng', 'để lại', 'để mà', 'để phần', 'để được', 'để đến nỗi', 'đối với', 'đồng thời', 'đủ', 'đủ dùng', 'đủ nơi', 'đủ số', 'đủ điều', 'đủ điểm', 'ơ', 'ơ hay', 'ơ kìa', 'ơi', 'ơi là', 'ư', 'ạ', 'ạ ơi', 'ấy', 'ấy là', 'ầu ơ', 'ắt', 'ắt hẳn', 'ắt là', 'ắt phải', 'ắt thật', 'ối dào', 'ối giời', 'ối giời ơi', 'ồ', 'ồ ồ', 'ổng', 'ớ', 'ớ này', 'ờ', 'ờ ờ', 'ở', 'ở lại', 'ở như', 'ở nhờ', 'ở năm', 'ở trên', 'ở vào', 'ở đây', 'ở đó', 'ở được', 'ủa', 'ứ hự', 'ứ ừ', 'ừ', 'ừ nhé', 'ừ thì', 'ừ ào', 'ừ ừ', 'ử','ok','hk','uk'])
#Hàm remove các từ stopword
def remove_stopwords(line):
    words = []
    for word in line.strip().split():
        if word not in stopword:
            words.append(word)
    return ' '.join(words)

# %%
# Khai báo mảng để lưu kết quả 
array_ranking_vendor = []
# Vòng lặp cho trang đầu tiên của tiki cho danh mục
for item_link in Link_Link:
    urls=[item_link]
    allLinkID = []

    totalUrl=0

    for i in range(0,len(urls)):
        numLoop=0
        driver.get(urls[i])
#         print("url: ",i)
        for numLoop in range(0,1):
            try:
                driver.find_element_by_xpath('#/html/head/meta[21]')
            except:
                pass
        page_source=(driver.page_source)
        soup = bs(page_source,"lxml")
        for link in soup.find_all('meta',{"name": "al:android:url"}):
            allLinkID.append(link.get('content'))

#     print("**************")
#     split_name_id = [x[10:len(allLinkID[0])] for x in allLinkID]
#     result_id = split_name_id[0].find('/')
#     allID = [x[result_id+1:len(allLinkID[0])] for x in split_name_id]
#     print(allID) 
print(allLinkID)
# Out:
# ['tikivn://products/2127575']

# %%
# Khai báo mảng để lưu kết quả 
array_ranking_vendor = []
information_vendor = []
s_name_vendor = []
s_seller_id = []
s_rating_average = []
s_price_of_product = []
s_review_count_product = []
s_repaid = []
s_avg_rating_point = []
s_review_count_vendor = []
s_total_follower = []
s_year_participate = []
s_product_cancell_rate = []
s_product_return_rate = []
s_total_product_seller_detail = []
s_certificate = []
s_complaint = []
s_average_price = []
s_ppm_rate = []
s_is_tikinow = []
s_is_best_price_guaranteed = []
s_is_freeship_tikifast = []
s_quantity_sold = []
s_count_logistic = []
# Vòng lặp cho trang đầu tiên của tiki cho danh mục
for item_link in Link_Link:
    urls=[item_link]
    allLinkID = []

    totalUrl=0

    for i in range(0,len(urls)):
        numLoop=0
        driver.get(urls[i])
#         print("url: ",i)
        for numLoop in range(0,1):
            try:
                driver.find_element_by_xpath('#/html/head/meta[21]')
            except:
                pass
        page_source=(driver.page_source)
        soup = bs(page_source,"lxml")
        for link in soup.find_all('meta',{"name": "al:android:url"}):
            allLinkID.append(link.get('content'))

#     print("**************")
    split_name_id = [x[10:len(allLinkID[0])] for x in allLinkID]
    if len(split_name_id) == 0:
        continue
    result_id = split_name_id[0].find('/')

    allID = [x[result_id+1:len(allLinkID[0])] for x in split_name_id] 
#lấy dữ liệu comment
    arrayjson=[]
    description=[]
    for i in allID:
    #lấy dữ liệu mô tả:
        page_description = 'https://tiki.vn/api/v2/products/'+ str(i) +'?platform=web&include=tag,images,gallery,promotions,badges,stock_item,variants,product_links,discount_tag,ranks,breadcrumbs,top_features,cta_desktop'
        description.append(page_description)
#         print(page_description)

    #lấy comment
    allComment=[]
    totalUrl=0

    #lấy mô tả description
    soup_description=""
    for i in range(0,len(description)):
#         print("url: ",i)
        driver.get(description[i])
        page_source=(driver.page_source)
        soup_description = bs(page_source,"lxml")
#         print(soup_description)
    #lấy mô tả và số sao của sản phẩm và tên nhà vendor
    des=[]
    for i in description:
        json_url = urllib.request.urlopen(i)
        data = json.loads(json_url.read())

        id_pro = data.get("id", None)
        
        targetContent = data.get("description", None)
        
        rating_average = data.get("rating_average", 0)

        if data['current_seller'] is not None:
            name_vendor = data['current_seller']['name']
            seller_id = data['current_seller']['id']
            product_id = data['current_seller']['product_id']
        else:
            name_vendor = 'None_vendor'
            seller_id = -1

        price_of_product = data.get("price", 0)

        review_count_product = data.get("review_count", 0)

        repaid = data.get("repaid", '111')
        
        quantity_sold_infor = data.get("quantity_sold", 0)
        quantity_sold = 0
        if quantity_sold_infor != 0:
            quantity_sold = quantity_sold_infor.get("value", 0)
        
        badges_new = data.get("badges_new", [])
        if len(badges_new) == 0:
            is_freeship_tikifast = 0
        else:
            is_freeship_tikifast = 1

        des.append(targetContent)
        
        #Lấy dữ liệu tikonow, freeship, shipfast
        get_url_tikinow = 'https://tiki.vn/api/v2/products/'+ str(product_id) +'/info?platform=web'
        
        if seller_id != -1:
            for number in range(1, 6):
                page_comment = 'https://tiki.vn/api/v2/reviews?limit=5&include=comments,contribute_info&sort=score%7Cdesc,id%7Cdesc,stars%7Call&page='+ str(number) +'&spid='+ str(product_id) +'&product_id='+ str(id_pro) +'&seller_id=' + str(seller_id)
#                 print(page_comment)
                arrayjson.append(page_comment)
        
    if seller_id != -1:
        page_seller_base = 'https://tiki.vn/api/shopping/v2/widgets/seller?seller_id=' + str(seller_id) + '&platform=desktop'
#         print(page_seller_base)
        json_url_seller_base = urllib.request.urlopen(page_seller_base)
        data_seller_base = json.loads(json_url_seller_base.read())

        data_seller_base = data_seller_base['data']

        data_seller_base = data_seller_base['seller']

        avg_rating_point = data_seller_base.get("avg_rating_point", 0)

        review_count_vendor = data_seller_base.get("review_count", 0)

        total_follower = data_seller_base.get("total_follower", 0)

        days_since_joined = data_seller_base.get("days_since_joined", 0)

        current_year = datetime.date.today().year
        year_participate = current_year - round(days_since_joined/365)

        page_seller_detail = 'https://api.tiki.vn/v2/categories?seller_id=' + str(seller_id)
        json_url_seller_detail = urllib.request.urlopen(page_seller_detail)
        data_seller_detail = json.loads(json_url_seller_detail.read())

        product_cancell_rate = data_seller_detail.get('order_cancell_rate', '0')
        product_return_rate = data_seller_detail.get('product_return_rate', '0')

        data_seller_detail = data_seller_detail['data']
        total_product_seller_detail = 0
        for value_product in data_seller_detail:
            total_product_seller_detail += value_product['product_count']


        #     print(rating_average)
        #     print(name_vendor)
        #     print(price_of_product)
        #     print(review_count)
        #     print(seller_id)
        # print(avg_rating_point)
        # print(review_count_vendor)
        # print(total_follower)
        # print(days_since_joined)
        # print(year_participate)
        # print(total_product_seller_detail)


        #tìm từ trong chuỗi
        #print(type(variable_name)) -> lấy loại của dữ liệu
        string_des = str(des)[1:-1]
        certificate=""
        if string_des.find('chứng nhận') > -1:
            certificate='has certificate'
        if string_des.find('chứng chỉ') > -1:
            certificate='has certificate'
        if string_des.find('tiêu chuẩn quốc tế') > -1:
            certificate='has certificate'
        if string_des.find('ISO 9001') > -1:
            certificate="ISO 9001"
        if string_des.find('ISO 14001') > -1:
            certificate="ISO 14001"
        if string_des.find('ISO') > -1:
            certificate="ISO"
        elif string_des.find('FDA') > -1:
            certificate="FDA"
        elif string_des.find('HCCP') > -1:
            certificate="HCCP"
        else:
            certificate="None"
    #     print(certificate)
    # lấy dữ liệu comment bỏ vào json
        comments=[]
        Allcomments=[]
        for i in arrayjson:
            #print("Url:",i)
            json_url = urllib.request.urlopen(i)
            data = json.loads(json_url.read())
            for dest in data['data']:
                targetContent = dest['content']
                targetRating = dest['rating']
                comment={
                    "star":targetRating,
                    "content": remove_stopwords(targetContent)
                }
#                 print(comments)
                comments.append(comment)
    #     writeToJson(comments)
    #     print(comments)

        if len(comments) > 0:
            total_comment = 0
            total=0
            allComment=[]

            for i in comments:
                if i['content'] != '':
                    total=total+1
                    total_comment += 1 
            contents=[]
            stars=[]

            for i in comments:
                contents.append((i['content']).lower())
                stars.append(i['star'])

            first_content = ''
            if len(contents) > 0:
                first_content = contents[0]
            if len(contents) > 0 and first_content != '' and first_content != '.':
                vectorizer = CountVectorizer()
                vectorizer.fit(contents)
                # print(vectorizer.vocabulary_)
                X_train = vectorizer.transform(contents)

                y_train=[]

                numNega=0
                numPosi=0
                for i in stars:
                    if i <= 3:
                        y_train.append(0)
                        numNega=numNega+1
                    else:
                        y_train.append(1)
                        numPosi=numPosi+1

                train_y = list(dict.fromkeys(y_train))
                count = 0
                for i in train_y:
                    count = count + 1
                if count == 1:
                    continue
                classifier = LogisticRegression()
                classifier.fit(X_train, y_train)
                # tach ra 500 xau
                y_train=[]
                x_train=[]
                x_train_bad=[]
                x_train_good=[]

                total=0
                for i in range(0,len(stars)):
                    if(stars[i]<=3):
                        if(contents[i] not in x_train_bad):
                            y_train.append(0)
                            x_train_bad.append(contents[i])
                            x_train.append(contents[i])
                            total=total+1
                    if(total==500):
                        break

                total=0
                for i in range(0,len(stars)):
                    if(stars[i]>3):
                        if(contents[i] not in x_train_good):
                            y_train.append(1)
                            x_train_good.append(contents[i])
                            x_train.append(contents[i])
                            total=total+1
                    if(total==len(x_train_bad)):
                        break

                vectorizer = CountVectorizer()
                vectorizer.fit(x_train)
                X_train = vectorizer.transform(x_train)
                classifier = LogisticRegression()
                classifier.fit(X_train, y_train)
                count_negative = 0
                for i in comments:
                    for j in i:
                        count_negative += classifier.predict(vectorizer.transform(['content']))[0]
                count_positive = total_comment - count_negative 
                Complaint = count_negative / total_comment
            else:
                count_negative = 0
                count_positive = 0
                for i in range(0,len(stars)):
                    if (stars[i] <= 3):
                        count_negative = count_negative + 1
                    else:
                        count_positive = count_positive + 1
                if total_comment != 0:
                    Complaint = count_negative / total_comment
                else:
                    Complaint = None
        else:
            Complaint = None
    else:
        continue
    
    #Kiểm tra hàng "lỗi or giao chậm"
    All_PPM_RATE =[]
    count_logistic=0
    count_error=0
    for item in comments:
        str_slowly= "chậm"
        str_error= "lỗi"
        if str_slowly  in item["content"]:
            item["logistis"] = str_slowly
            count_logistic += 1;
        else:
            item["logistis"] = ""
        if str_error in item["content"]:
            item["error"] = str_error
            count_error += 1;
        else:
            item["ppm"] = ""
        All_PPM_RATE.append(item)
#     print("Count hàng giao chậm = " + str(count_logistic), "\nCount hàng lỗi = " + str(count_error))
    #print(All_PPM_RATE)
    #Kiểm tra có bao nhiêu đánh giá hàng giao chậm hoặc lỗi
    
    #Lấy tikinow **********
    json_url_tikinow = urllib.request.urlopen(get_url_tikinow)
    data_tikinow = json.loads(json_url_tikinow.read())
    best_price_guaranteed = data_tikinow.get("best_price_guaranteed", [])
    
    is_best_price_guaranteed = 0
    if len(best_price_guaranteed) > 0:
        is_best_price_guaranteed = 1
    
    #Lấy ra các giá trị trong mục 'data'
    content_badges = data_tikinow.get("badges", None)
    if content_badges != None:
        is_tikinow = 0
        for element in content_badges:
            if element['code'] == 'tikinow':
                is_tikinow = 1
                break

    
    #1.2 ppm rate (part per milion) 30% (số đơn hàng bị lỗi / tổng số đơn hàng) => mỗi trang là 5 bình luận 
    #=> 10 trang là 50 comment (50SP)
    ppm_rate = (count_error/50) * 1000 # *1000 vì số lượng đơn hàng ít hơn 1/1000 so với tài liệu
    
    
    array_obj_infor_vendor = [
    {
        's_name_vendor': name_vendor,
        's_seller_id': seller_id,
        's_is_best_price_guaranteed': is_best_price_guaranteed,
        's_is_tikinow': is_tikinow,
        's_is_freeship_tikifast': is_freeship_tikifast,
        's_quantity_sold': quantity_sold,
        's_rating_average': rating_average,
        's_price_of_product': price_of_product,
        's_review_count_product': review_count_product,
        's_repaid': repaid,
        's_avg_rating_point': avg_rating_point,
        's_review_count_vendor': review_count_vendor,
        's_total_follower': total_follower,
        's_year_participate': year_participate,
        's_product_cancell_rate': product_cancell_rate,
        's_product_return_rate': product_return_rate,
        's_total_product_seller_detail': total_product_seller_detail,
        's_certificate': certificate,
        's_complaint': Complaint,
        's_count_logistic': count_logistic,
#         'average_price': average_price,
        's_ppm_rate': ppm_rate
    }
    ]
#     append thông tin tiêu chí vendor 
    information_vendor.append(array_obj_infor_vendor)
    
    s_name_vendor.append(name_vendor)
    s_seller_id.append(seller_id)
    s_is_best_price_guaranteed.append(is_best_price_guaranteed)
    s_is_tikinow.append(is_tikinow)
    s_is_freeship_tikifast.append(is_freeship_tikifast)
    s_quantity_sold.append(quantity_sold)
    s_rating_average.append(rating_average)
    s_price_of_product.append(price_of_product)
    s_review_count_product.append(review_count_product)
    s_repaid.append(repaid)
    s_avg_rating_point.append(avg_rating_point)
    s_review_count_vendor.append(review_count_vendor)
    s_total_follower.append(total_follower)
    s_year_participate.append(year_participate)
    s_product_cancell_rate.append(product_cancell_rate)
    s_product_return_rate.append(product_return_rate)
    s_total_product_seller_detail.append(total_product_seller_detail)
    s_certificate.append(certificate)
    s_complaint.append(Complaint)
    s_count_logistic.append(count_logistic)
#     s_average_price.append(average_price)
    s_ppm_rate.append(ppm_rate)


# print(information_vendor)
print('name_vendor: ') 
print(s_name_vendor)
print('\n')
print('is_best_price_guaranteed: ') 
print(s_is_best_price_guaranteed)
print('\n')
print('is_tikinow: ') 
print(s_is_tikinow)
print('\n')
print('is_freeship_tikifast: ') 
print(s_is_freeship_tikifast)
print('\n')
print('quantity_sold: ') 
print(s_quantity_sold)
print('\n')
print('rating_average: ') 
print(s_rating_average)
print('\n')
print('price_of_product: ') 
print(s_price_of_product)
print('\n')
print('review_count_product: ') 
print(s_review_count_product)
print('\n')
print('repaid: ') 
print(s_repaid)
print('\n')
print('avg_rating_point: ') 
print(s_avg_rating_point)
print('\n')
print('review_count_vendor: ') 
print(s_review_count_vendor)
print('\n')
print('total_follower: ') 
print(s_total_follower)
print('\n')
print('year_participate: ') 
print(s_year_participate)
print('\n')
print('product_cancell_rate: ') 
print(s_product_cancell_rate)
print('\n')
print('product_return_rate: ') 
print(s_product_return_rate)
print('\n')
print('total_product_seller_detail: ') 
print(s_total_product_seller_detail)
print('\n')
print('Certification: ') 
print(s_certificate)
print('\n')
print('Complaint: ') 
print(s_complaint)
print('\n')
print('Logistic: ')
print(s_count_logistic)
print('\n')
print('PPM rate: ')
print(s_ppm_rate)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-17-376d73487645> in <module>
#     143
#     144         page_seller_detail = 'https://api.tiki.vn/v2/categories?seller_id=' + str(seller_id)
# --> 145         json_url_seller_detail = urllib.request.urlopen(page_seller_detail)
#     146         data_seller_detail = json.loads(json_url_seller_detail.read())
#     147
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# ...

# %%
print(comment)

# %%
#lọc tiêu chí bằng correlation matrix

data = {
    's_name_vendor' : s_name_vendor,
    's_is_best_price_guaranteed' : s_is_best_price_guaranteed,
    's_is_tikinow' : s_is_tikinow,
    's_is_freeship_tikifast' : s_is_freeship_tikifast,
    's_quantity_sold' : s_quantity_sold,
    's_rating_average' : s_rating_average,
    's_price_of_product' : s_price_of_product,
    's_review_count_product' : s_review_count_product,
    's_repaid' : s_repaid,
    's_avg_rating_point' : s_avg_rating_point,
    's_review_count_vendor' : s_review_count_vendor,
    's_total_follower' : s_total_follower,
    's_year_participate' : s_year_participate,
    's_product_cancell_rate' : s_product_cancell_rate,
    's_product_return_rate' : s_product_return_rate,
    's_total_product_seller_detail' : s_total_product_seller_detail,
    's_certificate' : s_certificate,
    's_complaint' : s_complaint,
    's_count_logistic': s_count_logistic,
    's_ppm_rate' : s_ppm_rate
}

features = ['s_name_vendor', 's_is_best_price_guaranteed', 's_is_tikinow', 's_is_freeship_tikifast', 
            's_quantity_sold', 's_rating_average', 's_price_of_product', 
            's_review_count_product', 's_repaid', 's_avg_rating_point', 
            's_review_count_vendor', 's_total_follower', 's_year_participate', 
            's_product_cancell_rate', 's_product_return_rate', 's_certificate', 
            's_complaint', 's_count_logistic' ,'s_ppm_rate'
           ]

df = pd.DataFrame(data, columns = features)
df

# %%
# Using correlation matrix
correlation_matrix = df.corr()

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix of Breast Cancer data", y=-1)

plt.xlabel("cell nucleus features")

plt.ylabel("cell nucleus features")

plt.show()

array_targets = correlation_matrix[correlation_matrix>-1].index.values
print(array_targets)

# %%
# print(information_vendor)
name_supp = ['s_name_vendor']
array_targets = np.append(array_targets , name_supp)
arrray = information_vendor
print(array_targets)

# %%
# Xóa phần tử ko có trong list correlation matrix
for item_base in information_vendor:
    for item_detail in item_base:
        for key in list(item_detail):
            if key not in array_targets:
                item_detail.pop(key, None)
print(information_vendor)

# %%
# Tính điểm
array_ranking_vendor = []
for item_base in information_vendor:
    for item_detail in item_base:
        
        name_vendor = item_detail.get("s_name_vendor", None)

    # quality
        rating_average_product = item_detail.get("s_rating_average", None)
        review_count_product = item_detail.get("s_review_count_product", None)
        complaint = item_detail.get("s_complaint", None)
        ppm_rate = item_detail.get("s_ppm_rate", None)
        
    # price
        price_of_product = item_detail.get("s_price_of_product", None)

    # logistic    
        count_logistic = item_detail.get("s_count_logistic", None)
        
    # technology
        is_best_price_guaranteed = item_detail.get("s_is_best_price_guaranteed", None)
        is_tikinow = item_detail.get("s_is_tikinow", None)
        is_freeship_tikifast = item_detail.get("s_is_freeship_tikifast", None)
        quantity_sold = item_detail.get("s_quantity_sold", None)
        review_count_vendor = item_detail.get("s_review_count_vendor", None)
        avg_rating_point_vendor = item_detail.get("s_avg_rating_point", None)
        total_follower = item_detail.get("s_total_follower", None)
        year_participate = item_detail.get("s_year_participate", None)

        
    # 1. Quality 25%
        if rating_average_product != None:
            if rating_average_product >= 0 and rating_average_product < 4:
                point_rating_average_product = -10
            elif rating_average_product >= 4 and rating_average_product < 5:
                point_rating_average_product = 80
            else:
                point_rating_average_product = 95
        else:
            point_rating_average_product = 0
    
    
        if review_count_product != None:
            if review_count_product == 0 and review_count_product < 10:
                point_review_count_product = 10
            elif review_count_product >= 10 and review_count_product < 50:
                point_review_count_product = 30
            elif review_count_product >= 50 and review_count_product < 100:
                point_review_count_product = 70
            elif review_count_product >= 100:
                point_review_count_product = 100
            else:
                point_review_count_product = 0
        else:
            point_review_count_product = 0

            
        if complaint != None:
            if complaint == 0:
                point_complaint = 100
            elif complaint > 0 and complaint <= 0.5:
                point_complaint = 80
            elif complaint > 0.5 and complaint <= 1.25:
                point_complaint = 60
            elif complaint > 1.25 and complaint <= 3:
                point_complaint = 40
            elif complaint > 3 and complaint <= 5:
                point_complaint = 20
            else:
                point_complaint = 1
        else:
            point_complaint = 0
          
        
        if ppm_rate != None:
            if ppm_rate >= 0 and ppm_rate <= 10:
                point_ppm_rate = 100
            elif ppm_rate > 10 and ppm_rate <= 25:
                point_ppm_rate = 80
            elif ppm_rate > 25 and ppm_rate <= 50:
                point_ppm_rate = 60
            elif ppm_rate > 50 and ppm_rate <= 200:
                point_ppm_rate = 40
            elif ppm_rate > 200 and ppm_rate <= 999:
                point_ppm_rate = 20
            else:
                point_ppm_rate = 1
        else:
            point_ppm_rate = 0
        
        
        # Total Quality 25%
        Quality = (point_complaint * 30/100) + (point_ppm_rate * 30/100) + (point_review_count_product * 20/100) + (point_rating_average_product * 20/100)
        
        
    # 2. Pricing 25%
        Pricing = ((price_of_product - average_price)/average_price)*100

        if Pricing >= 10:
            point_price = 100
        elif Pricing >= 0 and Pricing < 10:
            point_price = 75 + (abs(round(Pricing)*(25/10))/100)
        else:
            point_price = 1 + (abs(round(Pricing)*(74/4))/100)
        

    # 3. Logistic 25%
        if count_logistic != None:
            if count_logistic == 0:
                point_logistic = 100
            elif count_logistic > 0 and count_logistic < 5:
                point_logistic = 70
            elif count_logistic >= 5 and count_logistic < 10:
                point_logistic = 30
            else:
                point_logistic = 0
        else:
            point_logistic = 0
    
    # 4. Technology 25%
    
        if is_best_price_guaranteed == 1:
            point_is_best_price_guaranteed = 100
        else: 
            point_is_best_price_guaranteed = 0
        
        
        if is_tikinow == 1:
            point_is_tikinow = 100
        else: 
            point_is_tikinow = 0
            
            
        if is_freeship_tikifast == 1:
            point_is_freeship_tikifast= 100
        else: 
            point_is_freeship_tikifast = 0
           
        
        if quantity_sold >= 0 and quantity_sold < 100:
            point_quantity_sold = 10
        elif quantity_sold >= 100 and quantity_sold < 300:
            point_quantity_sold = 30
        elif quantity_sold >= 300 and quantity_sold < 600:
            point_quantity_sold = 50
        elif quantity_sold >= 600 and quantity_sold < 1000:
            point_quantity_sold = 70
        elif quantity_sold >= 1000 and quantity_sold < 5000:
            point_quantity_sold = 80
        elif quantity_sold >= 5000 and quantity_sold < 10000:
            point_quantity_sold = 90
        elif quantity_sold >= 10000:
            point_quantity_sold = 100
        else:
            point_quantity_sold = 0
            

        if review_count_vendor >= 0 and review_count_vendor < 100:
            point_review_count_vendor = 10
        elif review_count_vendor >= 100 and review_count_vendor < 300:
            point_review_count_vendor = 20
        elif review_count_vendor >= 300 and review_count_vendor < 600:
            point_review_count_vendor = 30
        elif review_count_vendor >= 600 and review_count_vendor < 1000:
            point_review_count_vendor = 40
        elif review_count_vendor >= 1000 and review_count_vendor < 5000:
            point_review_count_vendor = 50
        elif review_count_vendor >= 5000 and review_count_vendor < 10000:
            point_review_count_vendor = 60
        elif review_count_vendor >= 10000 and review_count_vendor < 20000:
            point_review_count_vendor = 70
        elif review_count_vendor >= 20000 and review_count_vendor < 30000:
            point_review_count_vendor = 80
        elif review_count_vendor >= 30000 and review_count_vendor < 40000:
            point_review_count_vendor = 90
        elif review_count_vendor >= 50000:
            point_review_count_vendor = 100
        else:
            point_review_count_vendor = 0

         
        if avg_rating_point_vendor >= 0  and avg_rating_point_vendor < 3:
            point_avg_rating_point_vendor = 0
        elif avg_rating_point_vendor >= 3 and avg_rating_point_vendor < 4:
            point_avg_rating_point_vendor = 10
        elif avg_rating_point_vendor >= 4.0 and avg_rating_point_vendor < 4.2:
            point_avg_rating_point_vendor = 20
        elif avg_rating_point_vendor >= 4.2 and avg_rating_point_vendor < 4.4:
            point_avg_rating_point_vendor = 30
        elif avg_rating_point_vendor >= 4.4 and avg_rating_point_vendor < 4.6:
            point_avg_rating_point_vendor = 50
        elif avg_rating_point_vendor >= 4.6 and avg_rating_point_vendor < 4.8:
            point_avg_rating_point_vendor = 70
        elif avg_rating_point_vendor >= 4.8:
            point_avg_rating_point_vendor = 100
        else:
            point_avg_rating_point_vendor = -10
            
            
        if total_follower >= 0 and total_follower < 100:
            point_total_follower = 10
        elif total_follower >= 100 and total_follower < 300:
            point_total_follower = 20
        elif total_follower >= 300 and total_follower < 600:
            point_total_follower = 30
        elif total_follower >= 600 and total_follower < 1000:
            point_total_follower = 40
        elif total_follower >= 1000 and total_follower < 5000:
            point_total_follower = 50
        elif total_follower >= 5000 and total_follower < 10000:
            point_total_follower = 60
        elif total_follower >= 10000 and total_follower < 20000:
            point_total_follower = 70
        elif total_follower >= 20000 and total_follower < 30000:
            point_total_follower = 80
        elif total_follower >= 30000 and total_follower < 40000:
            point_total_follower = 90
        elif total_follower >= 50000:
            point_total_follower  = 100
        else:
            point_total_follower = 0
        
        
        if year_participate == 2021:
            point_year_participate = 50
        elif year_participate == 2020:
            point_year_participate = 60
        elif year_participate == 2019:
            point_year_participate = 70
        elif year_participate == 2018:
            point_year_participate = 80
        elif year_participate == 2017:
            point_year_participate = 90
        else:
            point_year_participate = 0
        
        point_technology = (point_is_best_price_guaranteed * 12.5/100) + (point_is_tikinow * 12.5/100) + (point_is_freeship_tikifast * 12.5/100) + (point_quantity_sold * 12.5/100) + (point_review_count_vendor * 12.5/100) + (point_avg_rating_point_vendor * 12.5/100)  + (point_total_follower * 12.5/100) + (point_year_participate * 12.5/100) 
        
        # Kết luận:
        Total_of_product = (Quality*25/100)  + (point_price*25/100) + (point_logistic*25/100) + (point_technology*25/100)
        Total_of_product = round(Total_of_product, 2)
        #     print(Total_of_product)

        
        rating_point = Total_of_product * 5/100

            
        if rating_point > avg_rating_point_vendor:
            rating_point = rating_point - 0.3
            
        if Total_of_product >= 80 and Total_of_product <= 100:
            Rank = 'A'
        elif Total_of_product >= 70 and Total_of_product < 80:
            Rank = 'B'
        elif Total_of_product >= 50 and Total_of_product < 69:
            Rank = 'C'
        else:
            Rank = 'D'
#         if rating_point >= 4.5:
#             Rank = 'A'
#         elif rating_point >= 4.2 and rating_point < 4.5:
#             Rank = 'B'
#         elif rating_point >= 3.9 and rating_point < 4.2:
#             Rank = 'C'
#         else:
#             Rank = 'D'
        
        information_ranking_vendor = str(name_vendor) + ' -- ' + str(Quality) + ' -- ' + str(point_price) + ' -- ' + str(point_logistic) + ' -- ' + str(point_technology) + ' -- ' + str(Total_of_product) + ' -- '  + str(avg_rating_point_vendor) +' -- ' + Rank 
    
    array_ranking_vendor.append(information_ranking_vendor)
    
# del information_vendor
# del s_name_vendor
# del s_seller_id
# del s_rating_average
# del s_price_of_product
# del s_review_count_product
# del s_repaid
# del s_avg_rating_point
# del s_review_count_vendor
# del s_total_follower
# del s_year_participate
# del s_product_cancell_rate
# del s_product_return_rate
# del s_total_product_seller_detail
# del s_certificate 
# del s_complaint
# del s_average_price 
# del s_ppm_rate 
# del s_is_tikinow 
# del s_is_best_price_guaranteed 
# del s_is_freeship_tikifast 
# del s_quantity_sold 
# del s_count_logistic

# %%
print(array_ranking_vendor)

# %%
import random
mylist = list(dict.fromkeys(array_ranking_vendor))

mylist.sort(key=lambda s: s[-1])

number_i = 0
number_j = 0
while number_i < len(mylist):
    word_i = [mylist[number_i]]
    name_i = [x[0:5] for x in word_i]
    number_j = number_i + 1
    while number_j < len(mylist):
        word_j = [mylist[number_j]]
        name_j = [x[0:5] for x in word_j]
        if name_j == name_i:
            mylist.remove(mylist[number_j])
            number_j = number_j - 1
        number_j = number_j + 1
    number_i = number_i + 1

accuracy_total_point = []
accuracy_ratting_vendor = []
for item in mylist:
    explore = item.split(' -- ')
    accuracy_total_point.append([float(explore[5])])
    accuracy_ratting_vendor.append(round(float(explore[6]),0))


for item in mylist:
    print(item + '\n')

a=['name_vendor', 'point_quality', 'point_price', 'point_logistic', 'point_technology', 'total_point', 'evaluateRating/TikiRating', 'Rank']

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import numpy as np
import matplotlib
import pickle

# sentences = np.array(accuracy_total_point).reshape(-1, 1)
sentences = accuracy_total_point
y = accuracy_ratting_vendor
sentences_train, sentences_test, y_train, y_test = train_test_split(
    sentences, y, test_size=0.25, random_state=1000)

# vectorizer = CountVectorizer()
# vectorizer.fit(sentences_train)
# X_train = vectorizer.transform(sentences_train)
# X_test  = vectorizer.transform(sentences_test)

classifier = LogisticRegression()
classifier.fit(sentences, y)
score = classifier.score(sentences, y)
print('Accuracy : '+ str(score))

# %%
# import mysql.connector

# for item in mylist:
#     explore = item.split(' -- ')
#     name_vendor = explore[0]
#     point_quality = explore[1]
#     point_price = explore[2]
#     point_logistic = explore[3]
#     point_technology = explore[4]
#     total_point = explore[5]
#     Rank = explore[7]

# #     # Kết nối database
#     mydb = mysql.connector.connect(
#       host="localhost",
#       user="root",
#       password="123456",
#       database="evaluation_vendor"
#     )
#     mycursor = mydb.cursor()

#     sql = "INSERT INTO information_ranking_vendor (name_vendor, id_url_product, quality, price, logistic, relationship, rank, total_point) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"
#     # Số 1 là ID URL tự ghi vào nha 
#     val = (name_vendor, '3' , point_quality, point_price, point_logistic, point_relationship, Rank, total_point)

#     mycursor.execute(sql, val)

#     mydb.commit()
#     print(mycursor.rowcount, "record inserted.")
